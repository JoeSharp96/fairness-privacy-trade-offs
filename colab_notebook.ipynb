# %% [markdown]
# # Google Colab - Project Notebook
# ## Installing the dependecies and project files

# %% [markdown]
# Install required dependencies from the GitHub repository

# %%
# %pip install git+https://github.com/JoeSharp96/fairness-privacy-trade-offs/

# %% [markdown]
# Clone the repository from GitHub

# %%
# %git clone https://github.com/JoeSharp96/fairness-privacy-trade-offs.git

# %% [markdown]
# Change current working directory to the cloned repository

# %%
# %cd /content/fairness-privacy-trade-offs/

# %% [markdown]
# ## Running the federated learning models
# The Federated Learning models can be run individually or all at once.

# %% [markdown]
# ### Run all three models
# Runs the ```adult_all.sh``` shell script. This runs all three models (non-DP, epsilon 5.0, and epsilon 1.0). Plots are then created using the ```reporting.py``` file.

# %%
# !bash adult_all.sh

# %% [markdown]
# ### Run models individually

# %%
# Runs and plots the baseline non-DP model
# !bash adult_non_dp.sh

# %%
# Runs and plots the Moderate DP (epsilon 5.0) model
# !bash adult_moderate_dp.sh

# %%
# Runs and plots the Strict DP (epsilon 1.0) model
# !bash adult_strict_dp.sh
